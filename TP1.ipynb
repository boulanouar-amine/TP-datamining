# %% [markdown]
# ### <center> TP1 boston and cambridge data cleaning

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Reading the file

# %%
boston = pd.read_csv("data/boston.csv")

cambridge = pd.read_csv("data/cambridge.csv")

df = pd.concat([boston, cambridge])

# %% [markdown]
# # Discovering the data set

# %%
df.shape
# Out:
# (4784, 106)

# %%
df.head(2)
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  5506  https://www.airbnb.com/rooms/5506  20191204162830   2019-12-04
# 1  6695  https://www.airbnb.com/rooms/6695  20191204162830   2019-12-04
#
#                                              name  \
# 0  **$79 Special **   Private! Minutes to center!
# 1                  $99 Special!! Home Away! Condo
#
#                                              summary  \
# 0  Private guest room with private bath, You do n...
# 1  Comfortable,  Fully Equipped private apartment...
#
#                                                space  \
# 0  **THE BEST Value in BOSTON!!*** PRIVATE GUEST ...
# 1  ** WELCOME *** FULL PRIVATE APARTMENT In a His...
#
#                                          description experiences_offered  \
# 0  Private guest room with private bath, You do n...                none
# 1  Comfortable,  Fully Equipped private apartment...                none
#
#                                neighborhood_overview  \
# 0  Peacful, Architecturally interesting, historic...
# 1  Peaceful, Architecturally interesting, histori...
#
#                                                notes  \
# 0  Guest room is on the 3rd floor,  Steps are req...
# 1  Check out some of the other accommodations we ...
#
#                                              transit  \
# 0  Excellent Access to all of Boston, Walk to Mus...
# 1  We are a 5 minute walk to the subway,  5 minut...
#
#                                               access  \
# 0  You get full access to the guest room with pri...
# 1  Full Private apartment.  1 bedroom,  kitchen, ...
#
#                                          interaction  \
# 0  We give guests privacy,  but we are available ...
# 1                                                NaN
#
#                    house_rules  thumbnail_url  medium_url  \
# 0  No Smoking in the Building.            NaN         NaN
# 1  No Smoking in the Building.            NaN         NaN
#
#                                          picture_url  xl_picture_url  host_id  \
# 0  https://a0.muscache.com/im/pictures/1598e8b6-5...             NaN     8229
# 1  https://a0.muscache.com/im/pictures/38ac4797-e...             NaN     8229
#
#                                  host_url host_name  host_since  \
# 0  https://www.airbnb.com/users/show/8229     Terry  2009-02-19
# 1  https://www.airbnb.com/users/show/8229     Terry  2009-02-19
#
#                           host_location  \
# 0  Boston, Massachusetts, United States
# 1  Boston, Massachusetts, United States
#
#                               host_about host_response_time  \
# 0  Relaxed,  Easy going, Accommodating.      within an hour
# 1  Relaxed,  Easy going, Accommodating.      within an hour
#
#   host_response_rate  host_acceptance_rate host_is_superhost  \
# 0               100%                   NaN                 f
# 1               100%                   NaN                 f
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/users/8229/profile_...
# 1  https://a0.muscache.com/im/users/8229/profile_...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/8229/profile_...            Roxbury
# 1  https://a0.muscache.com/im/users/8229/profile_...            Roxbury
#
#    host_listings_count  host_total_listings_count  \
# 0                  6.0                        6.0
# 1                  6.0                        6.0
#
#                      host_verifications host_has_profile_pic  \
# 0  ['email', 'phone', 'reviews', 'kba']                    t
# 1  ['email', 'phone', 'reviews', 'kba']                    t
#
#   host_identity_verified                     street neighbourhood  \
# 0                      t  Boston, MA, United States       Roxbury
# 1                      t  Boston, MA, United States       Roxbury
#
#   neighbourhood_cleansed  neighbourhood_group_cleansed    city state zipcode  \
# 0                Roxbury                           NaN  Boston    MA   02119
# 1                Roxbury                           NaN  Boston    MA   02119
#
#    market smart_location country_code        country  latitude  longitude  \
# 0  Boston     Boston, MA           US  United States  42.32981  -71.09559
# 1  Boston     Boston, MA           US  United States  42.32994  -71.09351
#
#   is_location_exact property_type        room_type  accommodates  bathrooms  \
# 0                 t   Guest suite  Entire home/apt             2        1.0
# 1                 t   Condominium  Entire home/apt             4        1.0
#
#    bedrooms  beds  bed_type  \
# 0       1.0   1.0  Real Bed
# 1       1.0   2.0  Real Bed
#
#                                            amenities  square_feet    price  \
# 0  {TV,"Cable TV",Internet,Wifi,"Air conditioning...        225.0  $145.00
# 1  {TV,"Cable TV",Internet,Wifi,"Air conditioning...          NaN  $169.00
#
#   weekly_price monthly_price security_deposit cleaning_fee  guests_included  \
# 0      $980.00     $3,000.00            $0.00       $60.00                1
# 1          NaN           NaN            $0.00       $80.00                2
#
#   extra_people  minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0        $0.00               3             730                       3
# 1        $8.00               3             730                       3
#
#    maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                       3                     730                     730
# 1                       3                     730                     730
#
#    minimum_nights_avg_ntm  maximum_nights_avg_ntm calendar_updated  \
# 0                     3.0                   730.0            today
# 1                     3.0                   730.0            today
#
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t               27               27               27
# 1                t               18               18               18
#
#    availability_365 calendar_last_scraped  number_of_reviews  \
# 0                27            2019-12-04                106
# 1                18            2019-12-04                115
#
#    number_of_reviews_ltm first_review last_review  review_scores_rating  \
# 0                     26   2009-03-21  2019-10-31                  95.0
# 1                     30   2009-08-06  2019-11-02                  96.0
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                    10.0                       10.0                   10.0
# 1                    10.0                       10.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                     9.0                 10.0
# 1                         10.0                     9.0                 10.0
#
#   requires_license                                            license  \
# 0                t  Exempt: This listing is a unit that has contra...
# 1                t                                         STR-404620
#
#                                jurisdiction_names instant_bookable  \
# 0  {"Massachusetts State"," Massachusetts State"}                t
# 1  {"Massachusetts State"," Massachusetts State"}                t
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f  strict_14_with_grace_period
# 1                        f  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
#
#    calculated_host_listings_count  \
# 0                               6
# 1                               6
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            6
# 1                                            6
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             0
# 1                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.81
# 1                                            0               0.91

# %%
# check columns
list(df.columns)
# Out:
# ['id',
#  'listing_url',
#  'scrape_id',
#  'last_scraped',
#  'name',
#  'summary',
#  'space',
#  'description',
#  'experiences_offered',
#  'neighborhood_overview',
#  'notes',
#  'transit',
#  'access',
#  'interaction',
#  'house_rules',
#  'thumbnail_url',
#  'medium_url',
#  'picture_url',
#  'xl_picture_url',
#  'host_id',
#  'host_url',
#  'host_name',
#  'host_since',
#  'host_location',
#  'host_about',
#  'host_response_time',
#  'host_response_rate',
#  'host_acceptance_rate',
#  'host_is_superhost',
#  'host_thumbnail_url',
#  'host_picture_url',
#  'host_neighbourhood',
#  'host_listings_count',
#  'host_total_listings_count',
#  'host_verifications',
#  'host_has_profile_pic',
#  'host_identity_verified',
#  'street',
#  'neighbourhood',
#  'neighbourhood_cleansed',
#  'neighbourhood_group_cleansed',
#  'city',
#  'state',
#  'zipcode',
#  'market',
#  'smart_location',
#  'country_code',
#  'country',
#  'latitude',
#  'longitude',
#  'is_location_exact',
#  'property_type',
#  'room_type',
#  'accommodates',
#  'bathrooms',
#  'bedrooms',
#  'beds',
#  'bed_type',
#  'amenities',
#  'square_feet',
#  'price',
#  'weekly_price',
#  'monthly_price',
#  'security_deposit',
#  'cleaning_fee',
#  'guests_included',
#  'extra_people',
#  'minimum_nights',
#  'maximum_nights',
#  'minimum_minimum_nights',
#  'maximum_minimum_nights',
#  'minimum_maximum_nights',
#  'maximum_maximum_nights',
#  'minimum_nights_avg_ntm',
#  'maximum_nights_avg_ntm',
#  'calendar_updated',
#  'has_availability',
#  'availability_30',
#  'availability_60',
#  'availability_90',
#  'availability_365',
#  'calendar_last_scraped',
#  'number_of_reviews',
#  'number_of_reviews_ltm',
#  'first_review',
#  'last_review',
#  'review_scores_rating',
#  'review_scores_accuracy',
#  'review_scores_cleanliness',
#  'review_scores_checkin',
#  'review_scores_communication',
#  'review_scores_location',
#  'review_scores_value',
#  'requires_license',
#  'license',
#  'jurisdiction_names',
#  'instant_bookable',
#  'is_business_travel_ready',
#  'cancellation_policy',
#  'require_guest_profile_picture',
#  'require_guest_phone_verification',
#  'calculated_host_listings_count',
#  'calculated_host_listings_count_entire_homes',
#  'calculated_host_listings_count_private_rooms',
#  'calculated_host_listings_count_shared_rooms',
#  'reviews_per_month']

# %%
# check data types
df.dtypes
# Out:
# id                                                int64
# listing_url                                      object
# scrape_id                                         int64
# last_scraped                                     object
# name                                             object
# summary                                          object
# space                                            object
# description                                      object
# experiences_offered                              object
# neighborhood_overview                            object
# notes                                            object
# transit                                          object
# access                                           object
# interaction                                      object
# house_rules                                      object
# thumbnail_url                                   float64
# medium_url                                      float64
# picture_url                                      object
# xl_picture_url                                  float64
# host_id                                           int64
# host_url                                         object
# host_name                                        object
# host_since                                       object
# host_location                                    object
# host_about                                       object
# host_response_time                               object
# host_response_rate                               object
# host_acceptance_rate                            float64
# host_is_superhost                                object
# host_thumbnail_url                               object
# host_picture_url                                 object
# host_neighbourhood                               object
# host_listings_count                             float64
# host_total_listings_count                       float64
# host_verifications                               object
# host_has_profile_pic                             object
# host_identity_verified                           object
# street                                           object
# neighbourhood                                    object
# neighbourhood_cleansed                           object
# neighbourhood_group_cleansed                    float64
# city                                             object
# state                                            object
# zipcode                                          object
# market                                           object
# smart_location                                   object
# country_code                                     object
# country                                          object
# latitude                                        float64
# longitude                                       float64
# is_location_exact                                object
# property_type                                    object
# room_type                                        object
# accommodates                                      int64
# bathrooms                                       float64
# bedrooms                                        float64
# beds                                            float64
# bed_type                                         object
# amenities                                        object
# square_feet                                     float64
# price                                            object
# weekly_price                                     object
# monthly_price                                    object
# security_deposit                                 object
# cleaning_fee                                     object
# guests_included                                   int64
# extra_people                                     object
# minimum_nights                                    int64
# maximum_nights                                    int64
# minimum_minimum_nights                            int64
# maximum_minimum_nights                            int64
# minimum_maximum_nights                            int64
# maximum_maximum_nights                            int64
# minimum_nights_avg_ntm                          float64
# maximum_nights_avg_ntm                          float64
# calendar_updated                                 object
# has_availability                                 object
# availability_30                                   int64
# availability_60                                   int64
# availability_90                                   int64
# availability_365                                  int64
# calendar_last_scraped                            object
# number_of_reviews                                 int64
# number_of_reviews_ltm                             int64
# first_review                                     object
# last_review                                      object
# review_scores_rating                            float64
# review_scores_accuracy                          float64
# review_scores_cleanliness                       float64
# review_scores_checkin                           float64
# review_scores_communication                     float64
# review_scores_location                          float64
# review_scores_value                             float64
# requires_license                                 object
# license                                          object
# jurisdiction_names                               object
# instant_bookable                                 object
# is_business_travel_ready                         object
# cancellation_policy                              object
# require_guest_profile_picture                    object
# require_guest_phone_verification                 object
# calculated_host_listings_count                    int64
# calculated_host_listings_count_entire_homes       int64
# calculated_host_listings_count_private_rooms      int64
# calculated_host_listings_count_shared_rooms       int64
# reviews_per_month                               float64
# dtype: object

# %%
# summary statistics
df.describe()
# Out:
#                  id     scrape_id  thumbnail_url  medium_url  xl_picture_url  \
# count  4.784000e+03  4.784000e+03            0.0         0.0             0.0
# mean   2.241147e+07  2.019118e+13            NaN         NaN             NaN
# std    1.189100e+07  3.454310e+07            NaN         NaN             NaN
# min    5.506000e+03  2.019113e+13            NaN         NaN             NaN
# 25%    1.307812e+07  2.019113e+13            NaN         NaN             NaN
# 50%    2.312290e+07  2.019120e+13            NaN         NaN             NaN
# 75%    3.286307e+07  2.019120e+13            NaN         NaN             NaN
# max    4.057364e+07  2.019120e+13            NaN         NaN             NaN
#
#             host_id  host_acceptance_rate  host_listings_count  \
# count  4.784000e+03                   0.0          4768.000000
# mean   7.763702e+07                   NaN           132.160864
# std    8.879122e+07                   NaN           305.920333
# min    7.969000e+03                   NaN             0.000000
# 25%    1.071376e+07                   NaN             1.000000
# 50%    3.128791e+07                   NaN             5.000000
# 75%    1.181230e+08                   NaN            26.000000
# max    3.132551e+08                   NaN          1795.000000
#
#        host_total_listings_count  neighbourhood_group_cleansed     latitude  \
# count                4768.000000                           0.0  4784.000000
# mean                  132.160864                           NaN    42.347111
# std                   305.920333                           NaN     0.027144
# min                     0.000000                           NaN    42.235760
# 25%                     1.000000                           NaN    42.334755
# 50%                     5.000000                           NaN    42.351570
# 75%                    26.000000                           NaN    42.365913
# max                  1795.000000                           NaN    42.401510
#
#          longitude  accommodates    bathrooms     bedrooms         beds  \
# count  4784.000000   4784.000000  4782.000000  4781.000000  4777.000000
# mean    -71.089688      3.245610     1.263802     1.308095     1.749215
# std       0.030705      2.086184     0.501924     0.903176     1.282660
# min     -71.172800      1.000000     0.000000     0.000000     0.000000
# 25%     -71.110785      2.000000     1.000000     1.000000     1.000000
# 50%     -71.088080      2.000000     1.000000     1.000000     1.000000
# 75%     -71.065180      4.000000     1.500000     2.000000     2.000000
# max     -70.995950     26.000000     6.000000    13.000000    22.000000
#
#        square_feet  guests_included  minimum_nights  maximum_nights  \
# count   133.000000      4784.000000     4784.000000     4784.000000
# mean    694.052632         1.711747       30.743102      810.057483
# std     368.151655         1.377176       42.893104      531.479199
# min       0.000000         1.000000        1.000000        1.000000
# 25%     470.000000         1.000000        2.000000      180.000000
# 50%     580.000000         1.000000        3.000000     1125.000000
# 75%    1000.000000         2.000000       90.000000     1125.000000
# max    2400.000000        16.000000     1000.000000    11250.000000
#
#        minimum_minimum_nights  maximum_minimum_nights  minimum_maximum_nights  \
# count             4784.000000             4784.000000             4784.000000
# mean                28.909281               32.247283              811.776965
# std                 42.019983               44.828114              526.061458
# min                  1.000000                1.000000                1.000000
# 25%                  1.000000                2.000000              365.000000
# 50%                  3.000000                5.000000             1125.000000
# 75%                 32.000000               90.000000             1125.000000
# max               1000.000000             1000.000000            11250.000000
#
#        maximum_maximum_nights  minimum_nights_avg_ntm  maximum_nights_avg_ntm  \
# count             4784.000000             4784.000000             4784.000000
# mean               814.576087               31.013503              814.487897
# std                523.151828               43.623485              523.236621
# min                  1.000000                1.000000                1.000000
# 25%                365.000000                2.000000              365.000000
# 50%               1125.000000                4.500000             1125.000000
# 75%               1125.000000               70.575000             1125.000000
# max              11250.000000             1000.000000            11250.000000
#
#        availability_30  availability_60  availability_90  availability_365  \
# count      4784.000000      4784.000000      4784.000000       4784.000000
# mean         13.599289        30.051421        47.632316        158.170778
# std          11.797111        23.285811        35.300201        132.083250
# min           0.000000         0.000000         0.000000          0.000000
# 25%           0.000000         0.000000         3.000000         25.000000
# 50%          13.000000        33.000000        57.000000        141.000000
# 75%          26.000000        54.000000        82.000000        292.000000
# max          30.000000        60.000000        90.000000        365.000000
#
#        number_of_reviews  number_of_reviews_ltm  review_scores_rating  \
# count        4784.000000            4784.000000           3900.000000
# mean           44.387542              15.807692             93.466923
# std            71.432207              23.074247              8.513868
# min             0.000000               0.000000             20.000000
# 25%             2.000000               0.000000             91.000000
# 50%            13.000000               5.000000             96.000000
# 75%            55.000000              24.000000             99.000000
# max           599.000000             147.000000            100.000000
#
#        review_scores_accuracy  review_scores_cleanliness  \
# count             3898.000000                3899.000000
# mean                 9.611339                   9.474224
# std                  0.854005                   0.878767
# min                  2.000000                   2.000000
# 25%                  9.000000                   9.000000
# 50%                 10.000000                  10.000000
# 75%                 10.000000                  10.000000
# max                 10.000000                  10.000000
#
#        review_scores_checkin  review_scores_communication  \
# count            3897.000000                  3900.000000
# mean                9.748525                     9.701538
# std                 0.741750                     0.786946
# min                 2.000000                     2.000000
# 25%                10.000000                    10.000000
# 50%                10.000000                    10.000000
# 75%                10.000000                    10.000000
# max                10.000000                    10.000000
#
#        review_scores_location  review_scores_value  \
# count             3898.000000          3898.000000
# mean                 9.653412             9.264495
# std                  0.717600             0.942306
# min                  2.000000             2.000000
# 25%                  9.000000             9.000000
# 50%                 10.000000             9.000000
# 75%                 10.000000            10.000000
# max                 10.000000            10.000000
#
#        calculated_host_listings_count  \
# count                     4784.000000
# mean                        22.538462
# std                         39.224137
# min                          1.000000
# 25%                          1.000000
# 50%                          4.000000
# 75%                         18.000000
# max                        147.000000
#
#        calculated_host_listings_count_entire_homes  \
# count                                  4784.000000
# mean                                     19.334239
# std                                      38.957244
# min                                       0.000000
# 25%                                       0.000000
# 50%                                       1.000000
# 75%                                      13.000000
# max                                     147.000000
#
#        calculated_host_listings_count_private_rooms  \
# count                                   4784.000000
# mean                                       3.131062
# std                                        6.796846
# min                                        0.000000
# 25%                                        0.000000
# 50%                                        0.000000
# 75%                                        3.000000
# max                                       33.000000
#
#        calculated_host_listings_count_shared_rooms  reviews_per_month
# count                                  4784.000000        3922.000000
# mean                                      0.030309           2.159357
# std                                       0.332442           2.208857
# min                                       0.000000           0.000000
# 25%                                       0.000000           0.440000
# 50%                                       0.000000           1.370000
# 75%                                       0.000000           3.300000
# max                                       5.000000          15.000000

# %% [markdown]
# # Data cleaning

# %% [markdown]
# after looking at the data set, we can see that there are some columns that are not useful for our analysis, so we will drop them.
# here is a table of the columns that we will drop and the reason why we will drop them:

# %% [markdown]
# | Column | Reason |
# | ------ | ------ |
# | id <br> host id <br> scrape_id | IDs are not needed |
# | calendar_last_scraped<br>neighbourhood<br>host_neighbourhood<br>host_total_listings_count<br> | duplicate of another column |
# | host_acceptance_rate <br/> neighbourhood_group_cleansed | null columns |
# | experiences_offered <br/> market <br/> country_code <br/> country <br/> has_availability <br/> jurisdiction_names <br/> is_business_travel_ready | columns with <br/> same value in all rows |
# | square_feet<br>weekly_price<br>monthly_price | Not enough values <br> (less than 50%) |
# | zipcode | Irrelevant data |
# | street <br>city <br>state <br>smart_location| columns that have over 90% of repeated values |

# %% [markdown]
# | <center>Column</center> | Reason |
# | ------ | ------ |
# | <table><tr><td>listing_url</td><td>thumbnail_url</td><td>medium_url</td><td>picture_url</td><td>xl_picture_url</td></tr><tr><td>host_url</td><td>host_thumbnail_url</td><td>host_picture_url</td></tr></table> | Links (url) |
# |<table><tr><td>name</td><td>summary</td><td>space</td><td>description</td></tr><tr><td>neighborhood_overview</td><td>notes</td><td>transit</td><td>access</td></tr><tr><td>house rules</td><td>host about</td><td>host_response_time</td><td>interaction</td></tr><tr><td>host verifications</td><td>host name</td><td>host location</td><td>street</td></tr><tr><td>calendar_updated</td><td>license</td><td>jurisdiction_names</td><td>smart location</td></tr><tr><td>market</td></tr></table>| Textual Data |
# |<table><tr><td>maximum_nights_avg_ntm</td><td>minimum_nights_avg_ntm</td><td>maximum_maximum_nights</td></tr><tr><td>minimum_maximum_nights</td><td>maximum_minimum_nights</td><td>minimum_minimum_nights</td></tr><tr><td>availability_60</td><td>availability_90</td><td>availability_365</td></tr></table> | Can be Calculated |

# %% [markdown]
# ## Gathering the columns that we will drop

# %%
# create an array to store the columns that shoud be deleted
columns_to_delete = []

# %% [markdown]
# - columns with url

# %%
# columns with url in the name
columns_with_url = [col for col in df.columns if 'url' in col]
# print columns not in columns_to_delete
print([col for col in columns_with_url if col not in columns_to_delete])
columns_to_delete.extend(columns_with_url)
# Out:
# ['listing_url', 'thumbnail_url', 'medium_url', 'picture_url', 'xl_picture_url', 'host_url', 'host_thumbnail_url', 'host_picture_url']

# %% [markdown]
# - columns with dates

# %%
date_columns = ['last_scraped', 'host_since', 'calendar_last_scraped', 'first_review', 'last_review']

# %% [markdown]
# - columns with textual data

# %%
# get all columns with string data type 
text_cols = df[df.columns[df.dtypes == 'object']] 
is_text = []

for col in text_cols:
    # if it is inuque 70% of the time
    if df[col].nunique() / df.shape[0] > 0.1:
        is_text.append(col)
print(len(is_text))
print([col for col in is_text if col not in columns_to_delete])

# don't delete the date_columns
is_text = [col for col in is_text if col not in date_columns]

columns_to_delete.extend(is_text)
# Out:
# 22
# ['name', 'summary', 'space', 'description', 'neighborhood_overview', 'notes', 'transit', 'access', 'interaction', 'house_rules', 'host_name', 'host_since', 'host_about', 'amenities', 'first_review', 'last_review', 'license']

# %% [markdown]
# - columns that can be calculated

# %%
# columns that can be calculated from other columns
calculated_cols = ['maximum_nights_avg_ntm', 'minimum_nights_avg_ntm', 'maximum_maximum_nights',
                   'minimum_maximum_nights', 'maximum_minimum_nights', 'minimum_minimum_nights',
                   'availability_60', 'availability_90', 'availability_365']

print([col for col in calculated_cols if col not in columns_to_delete])
columns_to_delete.extend(calculated_cols)
# Out:
# ['maximum_nights_avg_ntm', 'minimum_nights_avg_ntm', 'maximum_maximum_nights', 'minimum_maximum_nights', 'maximum_minimum_nights', 'minimum_minimum_nights', 'availability_60', 'availability_90', 'availability_365']

# %% [markdown]
# - columns with id

# %%
# columns with id in the name
# ignore host_identity_verified
columns_with_id = [col for col in df.columns if 'id' in col and col != 'host_identity_verified']
print(columns_with_id)
columns_to_delete.extend(columns_with_id)
# Out:
# ['id', 'scrape_id', 'host_id']

# %% [markdown]
# - columns duplicated of another column

# %%
# duplicate columns of other columns

duplicate_columns = []

for col in df.columns:
    for col2 in df.columns:
        if col != col2 and df[col].equals(df[col2]) and col not in duplicate_columns:
            duplicate_columns.append(col)
print(len(duplicate_columns))
print([col for col in duplicate_columns if col not in columns_to_delete])

columns_to_delete.extend(duplicate_columns)
# Out:
# 9
# ['last_scraped', 'host_acceptance_rate', 'host_listings_count', 'host_total_listings_count', 'neighbourhood_group_cleansed', 'calendar_last_scraped']

# %% [markdown]
# - cloumns with null values

# %%
# columns with all null values or same value on all rows
null_columns = df.columns[df.isnull().all()]

print([col for col in null_columns if col not in columns_to_delete])
columns_to_delete.extend(null_columns)
# Out:
# []

# %% [markdown]
# - columns with same value in all rows

# %%
# columns with same value on all rows
same_value_columns = df.columns[(df.nunique() == 1)]
print([col for col in same_value_columns if col not in columns_to_delete])
columns_to_delete.extend(same_value_columns)
# Out:
# ['experiences_offered', 'market', 'country_code', 'country', 'has_availability', 'jurisdiction_names', 'is_business_travel_ready']

# %% [markdown]
# - columns with less than 50% of values

# %%
# columns with more than 50% of the values missing
missing_values = df.columns[(df.isnull().sum() / df.shape[0]) > 0.5]
print([col for col in missing_values if col not in columns_to_delete])
columns_to_delete.extend(missing_values)
# Out:
# ['square_feet', 'weekly_price', 'monthly_price']

# %% [markdown]
# - irrelevant data

# %%
# irrelevant columns
irrelevant_columns = ['zipcode', 'requires_license', 'host_verifications','calendar_updated']
print([col for col in irrelevant_columns if col not in columns_to_delete])
columns_to_delete.extend(irrelevant_columns)
# Out:
# ['zipcode', 'requires_license', 'host_verifications', 'calendar_updated']

# %% [markdown]
# - columns with over 90% of repeated values

# %%
# columns with over 90% of the values the same

same_value_columns =[]

for col in df.columns:
    # calculate the percentage of the most common value
    values = df[col].value_counts()
    # check if it is over 90%
    for value in values:
        if value / df.shape[0] > 0.9:
            same_value_columns.append(col)
    
print([col for col in same_value_columns if col not in columns_to_delete])

columns_to_delete.extend(same_value_columns)
# Out:
# ['host_has_profile_pic', 'state', 'bed_type', 'require_guest_profile_picture', 'require_guest_phone_verification', 'calculated_host_listings_count_shared_rooms']

# %% [markdown]
# - `city` before deleting this column, we will keep only the rows from boston.
# `host_location` we only consider the listings in Boston, so this column is irrelevent.

# %%
df = df[df["city"].fillna("").str.lower().str.contains("boston") | df["city"].fillna("").str.lower().str.contains("cambridge")]
columns_to_delete.append("host_location")

# %% [markdown]
# * columns that appear to be invalide but they are not, so we will keep them:
#     - latitude
#     - longitude
#     - amenities

# %%
columns_to_delete = [col for col in columns_to_delete if col not in ['latitude', 'longitude', 'amenities']]

# %%
print("old shape: ", df.shape)
df = df.drop(columns=columns_to_delete)
print("new shape: ", df.shape)
# Out:
# old shape:  (4668, 106)
# new shape:  (4668, 46)

# %% [markdown]
# ### correlation

# %%
# we will calulate the correlation between the columns
df_copy = df.copy()

# handle categorical columns
categorical_cols = df_copy.select_dtypes(include=['object']).columns
for col in categorical_cols:
    df_copy[col] = df_copy[col].astype('category').cat.codes

# Calculate correlations
correlation = df_copy.corr()
correlation = correlation.abs().unstack()
correlation = correlation.sort_values(ascending=False)
correlation = correlation[correlation > 0.6]
correlation = correlation[correlation < 1]
correlation = pd.DataFrame(correlation).reset_index()
correlation.columns = ["column 1", "column 2", "correlation"]
correlation = correlation.drop_duplicates(subset="correlation")
correlation
# Out:
#                                        column 1  \
# 0   calculated_host_listings_count_entire_homes
# 2                                smart_location
# 6                         number_of_reviews_ltm
# 8                                          beds
# 10                          review_scores_value
# 12                                 accommodates
# 14                            number_of_reviews
# 16                                     bedrooms
# 18                       review_scores_accuracy
# 20                  review_scores_communication
# 22                         review_scores_rating
# 24                                 first_review
# 26                          review_scores_value
# 28               calculated_host_listings_count
# 30                        review_scores_checkin
# 32                           host_response_rate
# 34                            reviews_per_month
# 36                       review_scores_accuracy
# 38                           host_neighbourhood
# 40                                neighbourhood
# 42                         review_scores_rating
# 44                  review_scores_communication
#
#                                        column 2  correlation
# 0                calculated_host_listings_count     0.984825
# 2                                          city     0.968307
# 6                             reviews_per_month     0.844377
# 8                                  accommodates     0.843318
# 10                         review_scores_rating     0.784172
# 12                                     bedrooms     0.765313
# 14                        number_of_reviews_ltm     0.761880
# 16                                         beds     0.759531
# 18                         review_scores_rating     0.758589
# 20                         review_scores_rating     0.698019
# 22                    review_scores_cleanliness     0.673686
# 24                                  last_review     0.668249
# 26                       review_scores_accuracy     0.664393
# 28                           host_response_rate     0.659327
# 30                  review_scores_communication     0.656668
# 32  calculated_host_listings_count_entire_homes     0.650285
# 34                            number_of_reviews     0.624855
# 36                  review_scores_communication     0.624578
# 38                                neighbourhood     0.618473
# 40                       neighbourhood_cleansed     0.618234
# 42                        review_scores_checkin     0.612593
# 44                          review_scores_value     0.608950

# %% [markdown]
# we will keep `accommodates` because it sums up `beds` and `bedrooms`
#
# `review_scores_rating` groups the following
#
# - `review_scores_cleanliness`
# - `review_scores_checkin`
# - `review_scores_value`
# - `review_scores_accuracy`
# - `review_scores_communication`
# - `review_scores_location`
#
#
# `host_neighbourhood` and `neighbourhood` are copy of `neighbourhood_cleansed`.
#
# `calculated_host_listings_count_entire_homes` is very similar to `calculated_host_listings_count`.
#
# `calculated_host_listings_count_private_rooms ` is very similar to `calculated_host_listings_count`.
#
# `number_of_reviews_ltm` is the number of reviews left for the property in the last twelve we will keep just `number_of_reviews`.

# %%
# we will remove some of the columns that have a correlation of 60% or higher

correlated_cols = ["beds", "bedrooms",
                   "review_scores_value", "review_scores_accuracy", 
                   "review_scores_checkin", "review_scores_cleanliness",
                   "review_scores_communication", 
                   "review_scores_location","host_neighbourhood",
                   "neighbourhood", "calculated_host_listings_count_private_rooms",
                   "calculated_host_listings_count_entire_homes", "number_of_reviews_ltm"]


print("old shape: ", df.shape)
df = df.drop(columns=correlated_cols)
print("new shape: ", df.shape)
# Out:
# old shape:  (4668, 46)
# new shape:  (4668, 33)

# %% [markdown]
# # Data preprocessing

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4668 entries, 0 to 1275
# Data columns (total 33 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   host_since                      4652 non-null   object
#  1   host_response_time              4094 non-null   object
#  2   host_response_rate              4094 non-null   object
#  3   host_is_superhost               4652 non-null   object
#  4   host_identity_verified          4652 non-null   object
#  5   street                          4668 non-null   object
#  6   neighbourhood_cleansed          4668 non-null   object
#  7   city                            4668 non-null   object
#  8   smart_location                  4668 non-null   object
#  9   latitude                        4668 non-null   float64
#  10  longitude                       4668 non-null   float64
#  11  is_location_exact               4668 non-null   object
#  12  property_type                   4668 non-null   object
#  13  room_type                       4668 non-null   object
#  14  accommodates                    4668 non-null   int64
#  15  bathrooms                       4666 non-null   float64
#  16  amenities                       4668 non-null   object
#  17  price                           4668 non-null   object
#  18  security_deposit                3486 non-null   object
#  19  cleaning_fee                    4144 non-null   object
#  20  guests_included                 4668 non-null   int64
#  21  extra_people                    4668 non-null   object
#  22  minimum_nights                  4668 non-null   int64
#  23  maximum_nights                  4668 non-null   int64
#  24  availability_30                 4668 non-null   int64
#  25  number_of_reviews               4668 non-null   int64
#  26  first_review                    3821 non-null   object
#  27  last_review                     3821 non-null   object
#  28  review_scores_rating            3800 non-null   float64
#  29  instant_bookable                4668 non-null   object
#  30  cancellation_policy             4668 non-null   object
#  31  calculated_host_listings_count  4668 non-null   int64
#  32  reviews_per_month               3821 non-null   float64
# dtypes: float64(5), int64(7), object(21)
# memory usage: 1.2+ MB

# %% [markdown]
# ## Handeling date values

# %%
# all the date columns that are left
for col in [col for col in date_columns if col not in columns_to_delete]:
    df[col] = pd.to_datetime(df[col])

# %% [markdown]
# ## Handling missing values

# %%
missing = df.isna().sum()
missing = missing[missing > 0].sort_values(ascending=False)
missing_percentage = (missing / df.shape[0]) * 100
missing = pd.DataFrame(
    {'missing': missing, 'Percentage %': round(missing_percentage, 2)})
missing
# Out:
#                         missing  Percentage %
# security_deposit           1182         25.32
# review_scores_rating        868         18.59
# first_review                847         18.14
# last_review                 847         18.14
# reviews_per_month           847         18.14
# host_response_time          574         12.30
# host_response_rate          574         12.30
# cleaning_fee                524         11.23
# host_since                   16          0.34
# host_is_superhost            16          0.34
# host_identity_verified       16          0.34
# bathrooms                     2          0.04

# %% [markdown]
# filling the columns that have few missing values with the average

# %%
for col in missing.index:

    if missing.loc[col, "Percentage %"] < 5:

        # if it's a str column, fill with the most common value
        if df[col].dtype == "object":
            value = df[col].mode()[0]
            print(
                f"filling {col} with the most common value {value}")
            df[col] = df[col].fillna(df[col].mode()[0])

        # if it's a numerical column, fill with the most common value

        if df[col].dtype == "int" or df[col].dtype == "float":
            value = round(df[col].mean())
            print(
                f"filling {col} with the mean value {value}")

            df[col] = df[col].fillna(df[col].mean())
# Out:
# filling host_is_superhost with the most common value f
# filling host_identity_verified with the most common value f
# filling bathrooms with the mean value 1

# %%
# fill the rest with unknown
df["host_response_time"] = df["host_response_time"].fillna("unknown")

# assume that the missing values mean that the host does not have a review yet or a security deposit etc...
df["reviews_per_month"] = df["reviews_per_month"].fillna(0)
df["security_deposit"] = df["security_deposit"].fillna(0)
df["cleaning_fee"] = df["cleaning_fee"].fillna(0)

# drop the rows without the host since
df = df.dropna(subset=["host_since"])

# update the missing values
missing = df.isna().sum()
missing = missing[missing > 0].sort_values(ascending=False)
missing_percentage = (missing / df.shape[0]) * 100
missing = pd.DataFrame(
    {'missing': missing, 'Percentage %': round(missing_percentage, 2)})
missing
# Out:
#                       missing  Percentage %
# review_scores_rating      866         18.62
# first_review              845         18.16
# last_review               845         18.16
# host_response_rate        558         11.99

# %% [markdown]
# ## Fixing boolean columns

# %%
# if the column contains "t","f" we can convert it to bool
bool_cols = []
for col in df.columns:
    if df[col].nunique() == 2 and "t" in df[col].unique() and "f" in df[col].unique():
        bool_cols.append(col)

bool_cols
# Out:
# ['host_is_superhost',
#  'host_identity_verified',
#  'is_location_exact',
#  'instant_bookable']

# %%
# convert the columns to bool
for col in bool_cols:
    df[col] = df[col].map({"t": True, "f": False})
    df[col] = df[col].astype("bool")

# %% [markdown]
# ## Fixing currency cols

# %%
# currency cols are the one that have rows that start with $
currency_cols = []
for col in df.columns:
    if df[col].dtype == "object" and df[col].str.startswith("$").any():
        currency_cols.append(col)
        
currency_cols
# Out:
# ['price', 'security_deposit', 'cleaning_fee', 'extra_people']

# %%
# remove the $ and convert to float
for col in currency_cols:
    df[col] = df[col].str.replace("$", "").str.replace(",", "").astype(float)
    # fill the missing values with 0
    df[col] = df[col].fillna(0)

# %% [markdown]
# ## Other fixes

# %%
# having 1.2 bathrooms doesn't make sense
df["bathrooms"] = df["bathrooms"].astype(int)

# fixing percentage in host_response_rate to a float
df["host_response_rate"] = df["host_response_rate"].str.replace("%", "").astype(float)
df["host_response_rate"] = df["host_response_rate"].fillna(0)

# %% [markdown]
# ## Handeling amenities

# %%
import re
from itertools import chain

# Use regular expression to remove unwanted characters
df["amenities"] = df["amenities"].str.split(",")

# remove {,}," and extra spaces
df["amenities"] = df["amenities"].apply(
    lambda x: [re.sub(r'["{}]', "", a).strip() for a in x])

# remove empty strings and translation missing
df["amenities"] = df["amenities"].apply(
    lambda x: [a for a in x if a and not a.startswith("translation missing: ")])

# flatten the list of lists
df_amenities = pd.Series(list(chain.from_iterable(
    df["amenities"].tolist()))).value_counts()
df_amenities = df_amenities.reset_index()  # convert to dataframe
df_amenities.columns = ["amenities", "count"]  # rename columns

df_amenities
# Out:
#                           amenities  count
# 0                              Wifi   4549
# 1                           Heating   4513
# 2                    Smoke detector   4510
# 3                        Essentials   4405
# 4          Carbon monoxide detector   4238
# 5                           Hangers   4169
# 6                           Kitchen   4070
# 7                        Hair dryer   3993
# 8                  Air conditioning   3960
# 9                              Iron   3929
# 10                          Shampoo   3921
# 11        Laptop friendly workspace   3579
# 12                               TV   3573
# 13                           Washer   3350
# 14                            Dryer   3330
# 15                        Hot water   3065
# 16                     Refrigerator   2776
# 17                Fire extinguisher   2714
# 18                        Microwave   2655
# 19                     Coffee maker   2413
# 20            Dishes and silverware   2389
# 21                    Self check-in   2326
# 22                       Bed linens   2290
# 23                             Oven   2236
# 24                            Stove   2185
# 25          Long term stays allowed   2006
# 26                   Cooking basics   1963
# 27                       Dishwasher   1760
# 28                         Cable TV   1703
# 29                    First aid kit   1639
# 30             Lock on bedroom door   1579
# 31                         Internet   1506
# 32              Family/kid friendly   1460
# 33              Free street parking   1254
# 34                 Private entrance   1220
# 35          Luggage dropoff allowed   1204
# 36                         Elevator   1165
# 37       Extra pillows and blankets   1157
# 38                           Keypad    934
# 39         Free parking on premises    851
# 40                          Lockbox    841
# 41                          Bathtub    759
# 42      No stairs or steps to enter    745
# 43                     Pets allowed    737
# 44                 Patio or balcony    700
# 45              Private living room    676
# 46                 24-hour check-in    653
# 47                              Gym    605
# 48               Garden or backyard    572
# 49        Paid parking off premises    519
# 50                      Safety card    514
# 51         Paid parking on premises    462
# 52         Pack ’n Play/travel crib    389
# 53                        Breakfast    375
# 54                  Host greets you    375
# 55                       Smart lock    343
# 56                 Indoor fireplace    332
# 57         Buzzer/wireless intercom    329
# 58        Well-lit path to entrance    315
# 59                        BBQ grill    310
# 60              Ethernet connection    292
# 61                            Other    225
# 62       Pets live on this property    213
# 63                   Building staff    209
# 64        Children’s books and toys    209
# 65            Room-darkening shades    206
# 66                    Wide hallways    204
# 67         Wide entrance for guests    197
# 68           Extra space around bed    178
# 69                    Wide entrance    173
# 70                       High chair    158
# 71                             Pool    155
# 72                Single level home    151
# 73                    Wide entryway    135
# 74              Suitable for events    130
# 75            Accessible-height bed    128
# 76                           Dog(s)    120
# 77                          Doorman    120
# 78         Cleaning before checkout    112
# 79         Accessible-height toilet    112
# 80      Flat path to guest entrance    106
# 81             Handheld shower head     97
# 82   Wide doorway to guest bathroom     96
# 83                             Crib     95
# 84                           Cat(s)     92
# 85                          Hot tub     87
# 86            Children’s dinnerware     85
# 87                      Pocket wifi     75
# 88            Disabled parking spot     70
# 89       Babysitter recommendations     70
# 90                           toilet     57
# 91         Wide clearance to shower     57
# 92                  Smoking allowed     54
# 93            Wheelchair accessible     53
# 94                    Outlet covers     51
# 95                      Stair gates     47
# 96                       Beachfront     45
# 97                        Baby bath     44
# 98                 Beach essentials     40
# 99       Fixed grab bars for shower     40
# 100                      Waterfront     38
# 101                      EV charger     34
# 102                Fireplace guards     30
# 103                    Game console     29
# 104                  Changing table     24
# 105                    Shower chair     22
# 106                   Window guards     22
# 107                  Ski-in/Ski-out     19
# 108                Step-free shower     17
# 109      Fixed grab bars for toilet     17
# 110                    Baby monitor     17
# 111                     Lake access     15
# 112         Bathtub with bath chair     14
# 113                Hot water kettle     10
# 114                    Other pet(s)      9
# 115                   Firm mattress      4
# 116             Table corner guards      4
# 117                Private bathroom      1
# 118            Pool with pool hoist      1
# 119          Electric profiling bed      1

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# remove the amenities that less than 10% from the largest value
amenities_threshold = df_amenities["count"].max() * 0.1
insufficient_amenities = df_amenities[df_amenities["count"]
                                      < amenities_threshold]

plt.figure(figsize=(10, 10))
sns.barplot(data=df_amenities, y="count", x="amenities")
plt.title("Amenities in Boston AirBnB")
plt.xticks([])
plt.axhline(y=amenities_threshold, color='r',
            linestyle='--')  # Add threshold line

# Add threshold label at the rightmost position
plt.text(plt.xlim()[1], amenities_threshold,
         'Amenities Threshold', color='r', va='bottom', ha='right')

plt.show()

# %%
# remove them from the dataframe
df_amenities = df_amenities[~df_amenities["amenities"].isin(
    insufficient_amenities["amenities"])]
df_amenities
# Out:
#                       amenities  count
# 0                          Wifi   4549
# 1                       Heating   4513
# 2                Smoke detector   4510
# 3                    Essentials   4405
# 4      Carbon monoxide detector   4238
# 5                       Hangers   4169
# 6                       Kitchen   4070
# 7                    Hair dryer   3993
# 8              Air conditioning   3960
# 9                          Iron   3929
# 10                      Shampoo   3921
# 11    Laptop friendly workspace   3579
# 12                           TV   3573
# 13                       Washer   3350
# 14                        Dryer   3330
# 15                    Hot water   3065
# 16                 Refrigerator   2776
# 17            Fire extinguisher   2714
# 18                    Microwave   2655
# 19                 Coffee maker   2413
# 20        Dishes and silverware   2389
# 21                Self check-in   2326
# 22                   Bed linens   2290
# 23                         Oven   2236
# 24                        Stove   2185
# 25      Long term stays allowed   2006
# 26               Cooking basics   1963
# 27                   Dishwasher   1760
# 28                     Cable TV   1703
# 29                First aid kit   1639
# 30         Lock on bedroom door   1579
# 31                     Internet   1506
# 32          Family/kid friendly   1460
# 33          Free street parking   1254
# 34             Private entrance   1220
# 35      Luggage dropoff allowed   1204
# 36                     Elevator   1165
# 37   Extra pillows and blankets   1157
# 38                       Keypad    934
# 39     Free parking on premises    851
# 40                      Lockbox    841
# 41                      Bathtub    759
# 42  No stairs or steps to enter    745
# 43                 Pets allowed    737
# 44             Patio or balcony    700
# 45          Private living room    676
# 46             24-hour check-in    653
# 47                          Gym    605
# 48           Garden or backyard    572
# 49    Paid parking off premises    519
# 50                  Safety card    514
# 51     Paid parking on premises    462

# %%
# one hot encoding based on df_amenities
df_amenities = df_amenities["amenities"].tolist()

df = df.join(df["amenities"].apply(lambda x: pd.Series(
    [True if a in x else False for a in df_amenities], index=df_amenities)))

df.drop(columns=["amenities"], inplace=True)

df.shape
# Out:
# (7068, 84)

# %% [markdown]
# ### Handling Categorical data

# %%
# for the rest of the str columns, we can convert them to categorical
categorical_cols = df.select_dtypes(include=['object']).columns
categorical_cols = [col for col in categorical_cols if col not in bool_cols]
categorical_cols
# Out:
# ['host_response_time',
#  'street',
#  'neighbourhood_cleansed',
#  'city',
#  'smart_location',
#  'property_type',
#  'room_type',
#  'cancellation_policy']

# %%
df = pd.get_dummies(df, columns=categorical_cols, drop_first=True)
df.shape
# Out:
# (7068, 176)

# %%
# show the types of the columns
df.dtypes
# Out:
# host_since                                          datetime64[ns]
# host_response_rate                                         float64
# host_is_superhost                                             bool
# host_identity_verified                                        bool
# latitude                                                   float64
# longitude                                                  float64
# is_location_exact                                             bool
# accommodates                                                 int64
# bathrooms                                                    int32
# price                                                      float64
# security_deposit                                           float64
# cleaning_fee                                               float64
# guests_included                                              int64
# extra_people                                               float64
# minimum_nights                                               int64
# maximum_nights                                               int64
# availability_30                                              int64
# number_of_reviews                                            int64
# first_review                                        datetime64[ns]
# last_review                                         datetime64[ns]
# review_scores_rating                                       float64
# instant_bookable                                              bool
# calculated_host_listings_count                               int64
# reviews_per_month                                          float64
# Wifi                                                          bool
# Heating                                                       bool
# Smoke detector                                                bool
# Essentials                                                    bool
# Carbon monoxide detector                                      bool
# Hangers                                                       bool
# Kitchen                                                       bool
# Hair dryer                                                    bool
# Air conditioning                                              bool
# Iron                                                          bool
# Shampoo                                                       bool
# Laptop friendly workspace                                     bool
# TV                                                            bool
# Washer                                                        bool
# Dryer                                                         bool
# Hot water                                                     bool
# Refrigerator                                                  bool
# Fire extinguisher                                             bool
# Microwave                                                     bool
# Coffee maker                                                  bool
# Dishes and silverware                                         bool
# Self check-in                                                 bool
# Bed linens                                                    bool
# Oven                                                          bool
# Stove                                                         bool
# Long term stays allowed                                       bool
# Cooking basics                                                bool
# Dishwasher                                                    bool
# Cable TV                                                      bool
# First aid kit                                                 bool
# Lock on bedroom door                                          bool
# Internet                                                      bool
# Family/kid friendly                                           bool
# Free street parking                                           bool
# Private entrance                                              bool
# Luggage dropoff allowed                                       bool
# Elevator                                                      bool
# Extra pillows and blankets                                    bool
# Keypad                                                        bool
# Free parking on premises                                      bool
# Lockbox                                                       bool
# Bathtub                                                       bool
# No stairs or steps to enter                                   bool
# Pets allowed                                                  bool
# Patio or balcony                                              bool
# Private living room                                           bool
# 24-hour check-in                                              bool
# Gym                                                           bool
# Garden or backyard                                            bool
# Paid parking off premises                                     bool
# Safety card                                                   bool
# Paid parking on premises                                      bool
# host_response_time_unknown                                    bool
# host_response_time_within a day                               bool
# host_response_time_within a few hours                         bool
# host_response_time_within an hour                             bool
# street_Boston (Jamaica Plain), MA, United States              bool
# street_Boston , MA, United States                             bool
# street_Boston, , MA, United States                            bool
# street_Boston, Allston, Ma, United States                     bool
# street_Boston, MA, United States                              bool
# street_Cambridge , MA, United States                          bool
# street_Cambridge, MA, United States                           bool
# street_East Boston, MA, United States                         bool
# street_East Cambridge, MA, United States                      bool
# street_Jamaica Plain, Boston, MA, United States               bool
# street_Mid-Cambridge, MA, United States                       bool
# neighbourhood_cleansed_Allston                                bool
# neighbourhood_cleansed_Area 2/MIT                             bool
# neighbourhood_cleansed_Back Bay                               bool
# neighbourhood_cleansed_Bay Village                            bool
# neighbourhood_cleansed_Beacon Hill                            bool
# neighbourhood_cleansed_Brighton                               bool
# neighbourhood_cleansed_Cambridge Highlands                    bool
# neighbourhood_cleansed_Cambridgeport                          bool
# neighbourhood_cleansed_Charlestown                            bool
# neighbourhood_cleansed_Chinatown                              bool
# neighbourhood_cleansed_Dorchester                             bool
# neighbourhood_cleansed_Downtown                               bool
# neighbourhood_cleansed_East Boston                            bool
# neighbourhood_cleansed_East Cambridge                         bool
# neighbourhood_cleansed_Fenway                                 bool
# neighbourhood_cleansed_Hyde Park                              bool
# neighbourhood_cleansed_Jamaica Plain                          bool
# neighbourhood_cleansed_Leather District                       bool
# neighbourhood_cleansed_Longwood Medical Area                  bool
# neighbourhood_cleansed_Mattapan                               bool
# neighbourhood_cleansed_Mid-Cambridge                          bool
# neighbourhood_cleansed_Mission Hill                           bool
# neighbourhood_cleansed_Neighborhood Nine                      bool
# neighbourhood_cleansed_North Cambridge                        bool
# neighbourhood_cleansed_North End                              bool
# neighbourhood_cleansed_Riverside                              bool
# neighbourhood_cleansed_Roslindale                             bool
# neighbourhood_cleansed_Roxbury                                bool
# neighbourhood_cleansed_South Boston                           bool
# neighbourhood_cleansed_South Boston Waterfront                bool
# neighbourhood_cleansed_South End                              bool
# neighbourhood_cleansed_Strawberry Hill                        bool
# neighbourhood_cleansed_The Port                               bool
# neighbourhood_cleansed_Wellington-Harrington                  bool
# neighbourhood_cleansed_West Cambridge                         bool
# neighbourhood_cleansed_West End                               bool
# neighbourhood_cleansed_West Roxbury                           bool
# city_Boston                                                   bool
# city_Boston                                                   bool
# city_Boston (Jamaica Plain)                                   bool
# city_Boston,                                                  bool
# city_Cambridge                                                bool
# city_Cambridge                                                bool
# city_East Boston                                              bool
# city_East Cambridge                                           bool
# city_Jamaica Plain, Boston                                    bool
# city_Mid-Cambridge                                            bool
# smart_location_Boston (Jamaica Plain), MA                     bool
# smart_location_Boston , MA                                    bool
# smart_location_Boston, , MA                                   bool
# smart_location_Boston, Allston, Ma                            bool
# smart_location_Boston, MA                                     bool
# smart_location_Cambridge , MA                                 bool
# smart_location_Cambridge, MA                                  bool
# smart_location_East Boston, MA                                bool
# smart_location_East Cambridge, MA                             bool
# smart_location_Jamaica Plain, Boston, MA                      bool
# smart_location_Mid-Cambridge, MA                              bool
# property_type_Barn                                            bool
# property_type_Bed and breakfast                               bool
# property_type_Boat                                            bool
# property_type_Boutique hotel                                  bool
# property_type_Bungalow                                        bool
# property_type_Cabin                                           bool
# property_type_Condominium                                     bool
# property_type_Cottage                                         bool
# property_type_Farm stay                                       bool
# property_type_Guest suite                                     bool
# property_type_Guesthouse                                      bool
# property_type_Hotel                                           bool
# property_type_House                                           bool
# property_type_In-law                                          bool
# property_type_Loft                                            bool
# property_type_Other                                           bool
# property_type_Serviced apartment                              bool
# property_type_Townhouse                                       bool
# property_type_Villa                                           bool
# room_type_Hotel room                                          bool
# room_type_Private room                                        bool
# room_type_Shared room                                         bool
# cancellation_policy_moderate                                  bool
# cancellation_policy_strict                                    bool
# cancellation_policy_strict_14_with_grace_period               bool
# cancellation_policy_super_strict_30                           bool
# cancellation_policy_super_strict_60                           bool
# dtype: object
